# %% [markdown]
# # Problemas de distribución de probabilidad

# %% [markdown]
# ## Distribución binomial
#
# En teoría de la probabilidad y estadística, la distribución binomial es la distribución de probabilidad discreta que da sólo dos resultados posibles en un experimento; por ejemplo, al lanzar una moneda, puede salir cara o cruz.

# %%
from scipy.stats import binom

# Definir todas las funciones de probabilidad relacionadas con esta distribución.

def dbinom(x, size, prob = 0.5):
    """
    Calcula la estimación puntual de la distribución binomial.
    """
    result = binom.pmf(k = x, n = size, p = prob, loc = 0)

    return result

def pbinom(q, size, prob = 0.5):
    """
    Calcula el acumulado de la distribución binomial.
    """
    result = binom.cdf(k = q, n = size, p = prob, loc = 0)

    return result

def qbinom(p, size, prob = 0.5):
    """
    Calcula la función cuantil a partir de la distribución binomial.
    """
    result = binom.ppf(q = p, n = size, p = prob, loc = 0)

    return result

def rbinom(n, size, prob = 0.5):
    """
    Genera variables aleatorias a partir de la distribución binomial.
    """
    result = binom.rvs(n = size, p = prob, size = n)

    return result

# %%
# Distribución binomial(10, 0.2), dónde n = 10 es el número de ensayos y p = 0.2 es la probabilidad de éxito en un solo ensayo
import numpy as np

np.random.seed(42)

print(f"Probability that a Binomial(10, 0.2) takes the value 2: {dbinom(2, size = 10, prob = 0.2)}")
print(f"Probability that a Binomial(10, 0.2) will take a value less than 2: {pbinom(2, size = 10, prob = 0.2)}")
print(f"Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? {qbinom(0.9, size = 10, prob = 0.2)}")
print(f"Generate 2000 random values from a Binomial(10, 0.2) distribution: {rbinom(2000, size = 10, prob = 0.2)}")

# %%
import matplotlib.pyplot as plt

np.random.seed(42)

size = 10
prob = 0.2
data = rbinom(2000, size = 10, prob = 0.2)

pmf = dbinom(data, size = size, prob = prob)
cdf = pbinom(data, size = size, prob = prob)
ppf = qbinom(data, size = size, prob = prob)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].stem(data, pmf, "r-")
axis[1].stem(data, cdf, "b-")
axis[2].stem(data, ppf, "g-")

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Ejercicio 1
#
# Escriba las funciones anteriores pero para distribuciones normales y uniformes.

# %%
#Uniform
from scipy.stats import uniform

#Densidad de probabilidad. PDF

def densidad_probabilidad (x,loc=0,scale=1):
    result=uniform.pdf(x,loc=0,scale=1)

    return result

#Funcion de distribucion acumulativa. CDF

def distrubucioin_acumulativa (x, loc=0, scale=1):
    result=uniform.cdf(x,loc=0,scale=1)

    return result

#Funcion puntos porcentuales.PPF

def pocetuales (q, loc=0, scale=1):
    result=uniform.ppf(q, loc=0, scale=1)

    return result

#Cariable random. RVS

def variable_random(loc,scale,size,random_state):
    result=uniform.rvs(loc=0,scale=1,size=1,random_state=None)

    return result

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import uniform
#grafico

loc=0
scale=1
x = np.linspace(-0.5, 1.5, 500)
q = np.linspace(0, 1, 500)

fig, axs = plt.subplots(3, 1)

# datos
pdf = uniform.pdf(x, loc=loc, scale=scale)
cdf = uniform.cdf(x, loc=loc, scale=scale)
ppf = uniform.ppf(q, loc=loc, scale=scale)


# PDF
axs[0].plot(x, pdf, color="b")
axs[0].set_title("PDF")
axs[0].grid()
axs[0].legend()

# CDF
axs[1].plot(x, cdf, color="g")
axs[1].set_title("CDF")
axs[1].grid()
axs[1].legend()

# PPF
axs[2].plot(q, ppf, color="r")
axs[2].set_title("PPF")
axs[2].grid()
axs[2].legend()

plt.xlabel('x / q')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_456/1382447786.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axs[0].legend()
# /tmp/ipykernel_456/1382447786.py:29: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axs[1].legend()
# /tmp/ipykernel_456/1382447786.py:35: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axs[2].legend()

# %%
 #Normal
from scipy.stats import norm


#Densidad de probabilidad. PDF

def densidad_probabilidad_normal (x,loc=0,scale=1):
    result=norm.pdf(x,loc=0,scale=1)

    return result

#Funcion de distribucion acumulativa. CDF

def distrubucioin_acumulativa_normal (x, loc=0, scale=1):
    result=norm.cdf(x,loc=0,scale=1)

    return result

#Funcion puntos porcentuales.PPF

def pocetuales (q, loc=0, scale=1):
    result=norm.ppf(q, loc=0, scale=1)

    return result

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import uniform
#grafico

loc=0
scale=1
x = np.linspace(-0.5, 1.5, 500)
q = np.linspace(0, 1, 500)

fig, axs = plt.subplots(3, 1)

# datos
pdf = norm.pdf(x, loc=loc, scale=scale)
cdf = norm.cdf(x, loc=loc, scale=scale)
ppf = norm.ppf(q, loc=loc, scale=scale)


# PDF
axs[0].plot(x, pdf, color="b")
axs[0].set_title("PDF")
axs[0].grid()
axs[0].legend()

# CDF
axs[1].plot(x, cdf, color="r")
axs[1].set_title("CDF")
axs[1].grid()
axs[1].legend()

# PPF
axs[2].plot(q, ppf, color="g")
axs[2].set_title("PPF")
axs[2].grid()
axs[2].legend()

plt.xlabel('x / q')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_456/38550985.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axs[0].legend()
# /tmp/ipykernel_456/38550985.py:29: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axs[1].legend()
# /tmp/ipykernel_456/38550985.py:35: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axs[2].legend()
